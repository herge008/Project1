# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import os

# Raw data file
source_file = ("Resources/MovieData_clean.csv")
df = pd.read_csv(source_file)
df.head()
# Out:
#    TMDB ID                            Title Release Date      Budget  \
# 0   110681             Kings of the Evening   2008-01-01         0.0
# 1    26163  The Decline And Fall Of America   2008-01-01      7500.0
# 2    13971                       Wild Child   2008-01-01  20000000.0
# 3     6933                  One Missed Call   2008-01-04        27.0
# 4    14423                     First Sunday   2008-01-11         0.0
#
#       Revenue    IMDB ID Rating  Runtime                   Genre  \
# 0     98682.0  tt1006904     PG   99 min                   Drama
# 1      1200.0  tt1786696    NaN  120 min             Documentary
# 2  21972336.0  tt1024255  PG-13  124 min  Comedy, Drama, Romance
# 3        26.0  tt0479968  PG-13   87 min         Horror, Mystery
# 4  38804615.0  tt0486578  PG-13   96 min    Comedy, Crime, Drama
#
#            Director  ...                  Awards  \
# 0   Andrew P. Jones  ...  8 wins & 1 nomination.
# 1       B.A. Brooks  ...                     NaN
# 2        Nick Moore  ...                     NaN
# 3      Eric Valette  ...          2 nominations.
# 4  David E. Talbert  ...                     NaN
#
#                                               Poster IMDB Rating IMDB Votes  \
# 0  https://m.media-amazon.com/images/M/MV5BMjA3OT...         6.0        234
# 1  https://m.media-amazon.com/images/M/MV5BMTMzNj...         5.2         13
# 2  https://m.media-amazon.com/images/M/MV5BNzUzYT...         6.1     46,716
# 3  https://m.media-amazon.com/images/M/MV5BMjA2NT...         4.0     30,026
# 4  https://m.media-amazon.com/images/M/MV5BMjE4MT...         4.5      9,203
#
#   DVD Release Date             Production Day of Release  Month of Release  \
# 0      01 Nov 2010       Indican Pictures        Tuesday           January
# 1              NaN                    NaN        Tuesday           January
# 2      17 Nov 2009     Universal Pictures        Tuesday           January
# 3      22 Apr 2008  Warner Bros. Pictures         Friday           January
# 4      13 May 2008                    NaN         Friday           January
#
#   Year of Release Revenue (Millions)
# 0            2008           0.098682
# 1            2008           0.001200
# 2            2008          21.972336
# 3            2008           0.000026
# 4            2008          38.804615
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(15,10))
plt.scatter(df["Budget"], df["Revenue"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.title("Budget vs Revenue)")
plt.xlabel("Budget")
plt.ylabel("Revenue")
plt.grid(True)
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(df["Budget"], df["Revenue"])
regress_values = df["Budget"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(15,10))
plt.scatter(df["Budget"], df["Revenue"], 
            marker="o", 
            facecolors="steelblue", 
            edgecolors="black"
           )
plt.plot(df["Budget"],
         regress_values,
         "r-",
         color = "firebrick"
        )
plt.annotate(line_eq,(0, 2000000000),
             fontsize=15,
             color="firebrick"
            )
plt.title("Movie Budget vs Revenue")
plt.xlabel("Budget")
plt.ylabel("Revenue")
print(f"The correlation coefficient is: {rvalue}")
plt.grid(True)
plt.show()
# Out:
# The correlation coefficient is: 0.7888986448950202
