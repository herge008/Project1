# %%
import requests
import os
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import time

# %%
csvpath=os.path.join("Resources","MovieData_Clean.csv")
movie_df=pd.read_csv(csvpath)

# %%
movie_df
# Out:
#       TMDB ID                            Title Release Date       Budget  \
# 0      110681             Kings of the Evening   2008-01-01          0.0
# 1       26163  The Decline And Fall Of America   2008-01-01       7500.0
# 2       13971                       Wild Child   2008-01-01   20000000.0
# 3        6933                  One Missed Call   2008-01-04         27.0
# 4       14423                     First Sunday   2008-01-11          0.0
# ...       ...                              ...          ...          ...
# 3167   503616                       Second Act   2018-12-21   16000000.0
# 3168   424783                        Bumblebee   2018-12-21  135000000.0
# 3169   426563                  Holmes & Watson   2018-12-25   42000000.0
# 3170   429197                             Vice   2018-12-25   60000000.0
# 3171   599290      WWR Tournament For Tomorrow   2018-12-30       4432.0
#
#           Revenue    IMDB ID Rating  Runtime                            Genre  \
# 0         98682.0  tt1006904     PG   99 min                            Drama
# 1          1200.0  tt1786696    NaN  120 min                      Documentary
# 2      21972336.0  tt1024255  PG-13  124 min           Comedy, Drama, Romance
# 3            26.0  tt0479968  PG-13   87 min                  Horror, Mystery
# 4      38804615.0  tt0486578  PG-13   96 min             Comedy, Crime, Drama
# ...           ...        ...    ...      ...                              ...
# 3167   72282227.0  tt2126357  PG-13  103 min           Comedy, Drama, Romance
# 3168  465895025.0  tt4701182  PG-13  114 min        Action, Adventure, Sci-Fi
# 3169   40462793.0  tt1255919  PG-13   90 min           Comedy, Crime, Mystery
# 3170   66266401.0  tt6266538      R  132 min         Biography, Comedy, Drama
# 3171      55647.0  tt9735328    NaN  172 min  Action, Drama, Game-Show, Sport
#
#               Director  ...  \
# 0      Andrew P. Jones  ...
# 1          B.A. Brooks  ...
# 2           Nick Moore  ...
# 3         Eric Valette  ...
# 4     David E. Talbert  ...
# ...                ...  ...
# 3167       Peter Segal  ...
# 3168     Travis Knight  ...
# 3169        Etan Cohen  ...
# 3170        Adam McKay  ...
# 3171               NaN  ...
#
#                                                  Poster IMDB Rating  \
# 0     https://m.media-amazon.com/images/M/MV5BMjA3OT...         6.0
# 1     https://m.media-amazon.com/images/M/MV5BMTMzNj...         5.2
# 2     https://m.media-amazon.com/images/M/MV5BNzUzYT...         6.1
# 3     https://m.media-amazon.com/images/M/MV5BMjA2NT...         4.0
# 4     https://m.media-amazon.com/images/M/MV5BMjE4MT...         4.5
# ...                                                 ...         ...
# 3167  https://m.media-amazon.com/images/M/MV5BMjQ2Mj...         5.8
# 3168  https://m.media-amazon.com/images/M/MV5BMjUwNj...         6.8
# 3169  https://m.media-amazon.com/images/M/MV5BZTNjMj...         3.8
# 3170  https://m.media-amazon.com/images/M/MV5BMTY1Nj...         7.2
# 3171  https://m.media-amazon.com/images/M/MV5BYWMxMT...         NaN
#
#      IMDB Votes DVD Release Date             Production Day of Release  \
# 0           234      01 Nov 2010       Indican Pictures        Tuesday
# 1            13              NaN                    NaN        Tuesday
# 2        46,716      17 Nov 2009     Universal Pictures        Tuesday
# 3        30,026      22 Apr 2008  Warner Bros. Pictures         Friday
# 4         9,203      13 May 2008                    NaN         Friday
# ...         ...              ...                    ...            ...
# 3167     18,337      12 Mar 2019               STXfilms         Friday
# 3168    115,881      02 Apr 2019     Paramount Pictures         Friday
# 3169     24,394      09 Apr 2019      Columbia Pictures        Tuesday
# 3170     97,207      02 Apr 2019     Annapurna Pictures        Tuesday
# 3171        NaN              NaN                    NaN         Sunday
#
#      Month of Release  Year of Release Revenue (Millions) Runtime (Min)
# 0             January             2008           0.098682          99.0
# 1             January             2008           0.001200         120.0
# 2             January             2008          21.972336         124.0
# 3             January             2008           0.000026          87.0
# 4             January             2008          38.804615          96.0
# ...               ...              ...                ...           ...
# 3167         December             2018          72.282227         103.0
# 3168         December             2018         465.895025         114.0
# 3169         December             2018          40.462793          90.0
# 3170         December             2018          66.266401         132.0
# 3171         December             2018           0.055647         172.0
#
# [3172 rows x 26 columns]

# %%
movie_df["Runtime (Min)"]=None

# %%
f = open(os.path.join("ErrorLogs","Data_Clean_Error_Log.txt"), "a")
for index, row in movie_df.iterrows():
    try:
        movie_df.loc[index,"Runtime (Min)"]=int(row["Runtime"].split(' min')[0])
    except:
        f.write(f"There was a problem removing minutes on movie with the TMDB ID {row['TMDB ID']}\n")
f.close()

# %%
movie_df
# Out:
#       TMDB ID                            Title Release Date       Budget  \
# 0      110681             Kings of the Evening   2008-01-01          0.0
# 1       26163  The Decline And Fall Of America   2008-01-01       7500.0
# 2       13971                       Wild Child   2008-01-01   20000000.0
# 3        6933                  One Missed Call   2008-01-04         27.0
# 4       14423                     First Sunday   2008-01-11          0.0
# ...       ...                              ...          ...          ...
# 3167   503616                       Second Act   2018-12-21   16000000.0
# 3168   424783                        Bumblebee   2018-12-21  135000000.0
# 3169   426563                  Holmes & Watson   2018-12-25   42000000.0
# 3170   429197                             Vice   2018-12-25   60000000.0
# 3171   599290      WWR Tournament For Tomorrow   2018-12-30       4432.0
#
#           Revenue    IMDB ID Rating  Runtime                            Genre  \
# 0         98682.0  tt1006904     PG   99 min                            Drama
# 1          1200.0  tt1786696    NaN  120 min                      Documentary
# 2      21972336.0  tt1024255  PG-13  124 min           Comedy, Drama, Romance
# 3            26.0  tt0479968  PG-13   87 min                  Horror, Mystery
# 4      38804615.0  tt0486578  PG-13   96 min             Comedy, Crime, Drama
# ...           ...        ...    ...      ...                              ...
# 3167   72282227.0  tt2126357  PG-13  103 min           Comedy, Drama, Romance
# 3168  465895025.0  tt4701182  PG-13  114 min        Action, Adventure, Sci-Fi
# 3169   40462793.0  tt1255919  PG-13   90 min           Comedy, Crime, Mystery
# 3170   66266401.0  tt6266538      R  132 min         Biography, Comedy, Drama
# 3171      55647.0  tt9735328    NaN  172 min  Action, Drama, Game-Show, Sport
#
#               Director  ...  \
# 0      Andrew P. Jones  ...
# 1          B.A. Brooks  ...
# 2           Nick Moore  ...
# 3         Eric Valette  ...
# 4     David E. Talbert  ...
# ...                ...  ...
# 3167       Peter Segal  ...
# 3168     Travis Knight  ...
# 3169        Etan Cohen  ...
# 3170        Adam McKay  ...
# 3171               NaN  ...
#
#                                                  Poster IMDB Rating  \
# 0     https://m.media-amazon.com/images/M/MV5BMjA3OT...         6.0
# 1     https://m.media-amazon.com/images/M/MV5BMTMzNj...         5.2
# 2     https://m.media-amazon.com/images/M/MV5BNzUzYT...         6.1
# 3     https://m.media-amazon.com/images/M/MV5BMjA2NT...         4.0
# 4     https://m.media-amazon.com/images/M/MV5BMjE4MT...         4.5
# ...                                                 ...         ...
# 3167  https://m.media-amazon.com/images/M/MV5BMjQ2Mj...         5.8
# 3168  https://m.media-amazon.com/images/M/MV5BMjUwNj...         6.8
# 3169  https://m.media-amazon.com/images/M/MV5BZTNjMj...         3.8
# 3170  https://m.media-amazon.com/images/M/MV5BMTY1Nj...         7.2
# 3171  https://m.media-amazon.com/images/M/MV5BYWMxMT...         NaN
#
#      IMDB Votes DVD Release Date             Production Day of Release  \
# 0           234      01 Nov 2010       Indican Pictures        Tuesday
# 1            13              NaN                    NaN        Tuesday
# 2        46,716      17 Nov 2009     Universal Pictures        Tuesday
# 3        30,026      22 Apr 2008  Warner Bros. Pictures         Friday
# 4         9,203      13 May 2008                    NaN         Friday
# ...         ...              ...                    ...            ...
# 3167     18,337      12 Mar 2019               STXfilms         Friday
# 3168    115,881      02 Apr 2019     Paramount Pictures         Friday
# 3169     24,394      09 Apr 2019      Columbia Pictures        Tuesday
# 3170     97,207      02 Apr 2019     Annapurna Pictures        Tuesday
# 3171        NaN              NaN                    NaN         Sunday
#
#      Month of Release  Year of Release Revenue (Millions) Runtime (Min)
# 0             January             2008           0.098682            99
# 1             January             2008           0.001200           120
# 2             January             2008          21.972336           124
# 3             January             2008           0.000026            87
# 4             January             2008          38.804615            96
# ...               ...              ...                ...           ...
# 3167         December             2018          72.282227           103
# 3168         December             2018         465.895025           114
# 3169         December             2018          40.462793            90
# 3170         December             2018          66.266401           132
# 3171         December             2018           0.055647           172
#
# [3172 rows x 26 columns]

# %%
movie_df.loc[movie_df["Year of Release"]<2019]
# Out:
#       TMDB ID                            Title Release Date       Budget  \
# 0      110681             Kings of the Evening   2008-01-01          0.0
# 1       26163  The Decline And Fall Of America   2008-01-01       7500.0
# 2       13971                       Wild Child   2008-01-01   20000000.0
# 3        6933                  One Missed Call   2008-01-04         27.0
# 4       14423                     First Sunday   2008-01-11          0.0
# ...       ...                              ...          ...          ...
# 3167   503616                       Second Act   2018-12-21   16000000.0
# 3168   424783                        Bumblebee   2018-12-21  135000000.0
# 3169   426563                  Holmes & Watson   2018-12-25   42000000.0
# 3170   429197                             Vice   2018-12-25   60000000.0
# 3171   599290      WWR Tournament For Tomorrow   2018-12-30       4432.0
#
#           Revenue    IMDB ID Rating  Runtime                            Genre  \
# 0         98682.0  tt1006904     PG   99 min                            Drama
# 1          1200.0  tt1786696    NaN  120 min                      Documentary
# 2      21972336.0  tt1024255  PG-13  124 min           Comedy, Drama, Romance
# 3            26.0  tt0479968  PG-13   87 min                  Horror, Mystery
# 4      38804615.0  tt0486578  PG-13   96 min             Comedy, Crime, Drama
# ...           ...        ...    ...      ...                              ...
# 3167   72282227.0  tt2126357  PG-13  103 min           Comedy, Drama, Romance
# 3168  465895025.0  tt4701182  PG-13  114 min        Action, Adventure, Sci-Fi
# 3169   40462793.0  tt1255919  PG-13   90 min           Comedy, Crime, Mystery
# 3170   66266401.0  tt6266538      R  132 min         Biography, Comedy, Drama
# 3171      55647.0  tt9735328    NaN  172 min  Action, Drama, Game-Show, Sport
#
#               Director  ...  \
# 0      Andrew P. Jones  ...
# 1          B.A. Brooks  ...
# 2           Nick Moore  ...
# 3         Eric Valette  ...
# 4     David E. Talbert  ...
# ...                ...  ...
# 3167       Peter Segal  ...
# 3168     Travis Knight  ...
# 3169        Etan Cohen  ...
# 3170        Adam McKay  ...
# 3171               NaN  ...
#
#                                                  Poster IMDB Rating  \
# 0     https://m.media-amazon.com/images/M/MV5BMjA3OT...         6.0
# 1     https://m.media-amazon.com/images/M/MV5BMTMzNj...         5.2
# 2     https://m.media-amazon.com/images/M/MV5BNzUzYT...         6.1
# 3     https://m.media-amazon.com/images/M/MV5BMjA2NT...         4.0
# 4     https://m.media-amazon.com/images/M/MV5BMjE4MT...         4.5
# ...                                                 ...         ...
# 3167  https://m.media-amazon.com/images/M/MV5BMjQ2Mj...         5.8
# 3168  https://m.media-amazon.com/images/M/MV5BMjUwNj...         6.8
# 3169  https://m.media-amazon.com/images/M/MV5BZTNjMj...         3.8
# 3170  https://m.media-amazon.com/images/M/MV5BMTY1Nj...         7.2
# 3171  https://m.media-amazon.com/images/M/MV5BYWMxMT...         NaN
#
#      IMDB Votes DVD Release Date             Production Day of Release  \
# 0           234      01 Nov 2010       Indican Pictures        Tuesday
# 1            13              NaN                    NaN        Tuesday
# 2        46,716      17 Nov 2009     Universal Pictures        Tuesday
# 3        30,026      22 Apr 2008  Warner Bros. Pictures         Friday
# 4         9,203      13 May 2008                    NaN         Friday
# ...         ...              ...                    ...            ...
# 3167     18,337      12 Mar 2019               STXfilms         Friday
# 3168    115,881      02 Apr 2019     Paramount Pictures         Friday
# 3169     24,394      09 Apr 2019      Columbia Pictures        Tuesday
# 3170     97,207      02 Apr 2019     Annapurna Pictures        Tuesday
# 3171        NaN              NaN                    NaN         Sunday
#
#      Month of Release  Year of Release Revenue (Millions) Runtime (Min)
# 0             January             2008           0.098682            99
# 1             January             2008           0.001200           120
# 2             January             2008          21.972336           124
# 3             January             2008           0.000026            87
# 4             January             2008          38.804615            96
# ...               ...              ...                ...           ...
# 3167         December             2018          72.282227           103
# 3168         December             2018         465.895025           114
# 3169         December             2018          40.462793            90
# 3170         December             2018          66.266401           132
# 3171         December             2018           0.055647           172
#
# [3172 rows x 26 columns]

# %%
movie_df
# Out:
#       TMDB ID                            Title Release Date       Budget  \
# 0      110681             Kings of the Evening   2008-01-01          0.0
# 1       26163  The Decline And Fall Of America   2008-01-01       7500.0
# 2       13971                       Wild Child   2008-01-01   20000000.0
# 3        6933                  One Missed Call   2008-01-04         27.0
# 4       14423                     First Sunday   2008-01-11          0.0
# ...       ...                              ...          ...          ...
# 3167   503616                       Second Act   2018-12-21   16000000.0
# 3168   424783                        Bumblebee   2018-12-21  135000000.0
# 3169   426563                  Holmes & Watson   2018-12-25   42000000.0
# 3170   429197                             Vice   2018-12-25   60000000.0
# 3171   599290      WWR Tournament For Tomorrow   2018-12-30       4432.0
#
#           Revenue    IMDB ID Rating  Runtime                            Genre  \
# 0         98682.0  tt1006904     PG   99 min                            Drama
# 1          1200.0  tt1786696    NaN  120 min                      Documentary
# 2      21972336.0  tt1024255  PG-13  124 min           Comedy, Drama, Romance
# 3            26.0  tt0479968  PG-13   87 min                  Horror, Mystery
# 4      38804615.0  tt0486578  PG-13   96 min             Comedy, Crime, Drama
# ...           ...        ...    ...      ...                              ...
# 3167   72282227.0  tt2126357  PG-13  103 min           Comedy, Drama, Romance
# 3168  465895025.0  tt4701182  PG-13  114 min        Action, Adventure, Sci-Fi
# 3169   40462793.0  tt1255919  PG-13   90 min           Comedy, Crime, Mystery
# 3170   66266401.0  tt6266538      R  132 min         Biography, Comedy, Drama
# 3171      55647.0  tt9735328    NaN  172 min  Action, Drama, Game-Show, Sport
#
#               Director  ...  \
# 0      Andrew P. Jones  ...
# 1          B.A. Brooks  ...
# 2           Nick Moore  ...
# 3         Eric Valette  ...
# 4     David E. Talbert  ...
# ...                ...  ...
# 3167       Peter Segal  ...
# 3168     Travis Knight  ...
# 3169        Etan Cohen  ...
# 3170        Adam McKay  ...
# 3171               NaN  ...
#
#                                                  Poster IMDB Rating  \
# 0     https://m.media-amazon.com/images/M/MV5BMjA3OT...         6.0
# 1     https://m.media-amazon.com/images/M/MV5BMTMzNj...         5.2
# 2     https://m.media-amazon.com/images/M/MV5BNzUzYT...         6.1
# 3     https://m.media-amazon.com/images/M/MV5BMjA2NT...         4.0
# 4     https://m.media-amazon.com/images/M/MV5BMjE4MT...         4.5
# ...                                                 ...         ...
# 3167  https://m.media-amazon.com/images/M/MV5BMjQ2Mj...         5.8
# 3168  https://m.media-amazon.com/images/M/MV5BMjUwNj...         6.8
# 3169  https://m.media-amazon.com/images/M/MV5BZTNjMj...         3.8
# 3170  https://m.media-amazon.com/images/M/MV5BMTY1Nj...         7.2
# 3171  https://m.media-amazon.com/images/M/MV5BYWMxMT...         NaN
#
#      IMDB Votes DVD Release Date             Production Day of Release  \
# 0           234      01 Nov 2010       Indican Pictures        Tuesday
# 1            13              NaN                    NaN        Tuesday
# 2        46,716      17 Nov 2009     Universal Pictures        Tuesday
# 3        30,026      22 Apr 2008  Warner Bros. Pictures         Friday
# 4         9,203      13 May 2008                    NaN         Friday
# ...         ...              ...                    ...            ...
# 3167     18,337      12 Mar 2019               STXfilms         Friday
# 3168    115,881      02 Apr 2019     Paramount Pictures         Friday
# 3169     24,394      09 Apr 2019      Columbia Pictures        Tuesday
# 3170     97,207      02 Apr 2019     Annapurna Pictures        Tuesday
# 3171        NaN              NaN                    NaN         Sunday
#
#      Month of Release  Year of Release Revenue (Millions) Runtime (Min)
# 0             January             2008           0.098682            99
# 1             January             2008           0.001200           120
# 2             January             2008          21.972336           124
# 3             January             2008           0.000026            87
# 4             January             2008          38.804615            96
# ...               ...              ...                ...           ...
# 3167         December             2018          72.282227           103
# 3168         December             2018         465.895025           114
# 3169         December             2018          40.462793            90
# 3170         December             2018          66.266401           132
# 3171         December             2018           0.055647           172
#
# [3172 rows x 26 columns]

# %%
# error=pd.read_csv("ErrorLogs/Data_Clean_Error_Log.txt")
error_frame=pd.DataFrame()
with open("ErrorLogs/Data_Clean_Error_Log.txt", 'r') as file:
    for line in file:
        mid=int(line.split()[-1])
#         print(mid)        
        error_frame=error_frame.append(movie_df.loc[movie_df["TMDB ID"]==int(mid)])

# %%
error_frame
# Out:
#       TMDB ID                                 Title Release Date      Budget  \
# 90     278267                         The Dead Walk   2008-06-06     50000.0
# 95     102308                        The 13th Alley   2008-06-13       150.0
# 138     13956                    Fly Me to the Moon   2008-08-15  25000000.0
# 318     20192                            Aloo Chaat   2009-03-20         0.0
# 348     76459                        The Other Bank   2009-05-01         0.0
# ...       ...                                   ...          ...         ...
# 2792   530388                         Comedy Ensani   2017-06-16     10000.0
# 2926   529211  Citizen Clark... A Life of Principle   2017-12-13         0.0
# 3004   464502                              Acrimony   2018-03-30  20000000.0
# 3009   458823               Acorn and the Firestorm   2018-04-06         0.0
# 3154   561594                             Twiceland   2018-12-07         0.0
#
#          Revenue    IMDB ID     Rating     Runtime  \
# 90     1200000.0  tt1189032  NOT RATED         NaN
# 95         250.0  tt1090634          R         NaN
# 138   41412264.0  tt1215056        NaN         NaN
# 318    1550000.0  tt1305840        NaN         NaN
# 348     750000.0  tt2517852        NaN         NaN
# ...          ...        ...        ...         ...
# 2792     10000.0  tt6224580        NaN         NaN
# 2926    400000.0  tt3533612        NaN         NaN
# 3004  34764055.0  tt0393024  Not Rated  1 h 25 min
# 3009      2621.0  tt5957104        NaN         NaN
# 3154    186078.0  tt9386922        NaN         NaN
#
#                                    Genre                         Director  \
# 90                                Horror             Michael Clinkenbeard
# 95                                Horror                     Bobb Hopkins
# 138   Adventure, Comedy, Fantasy, Sci-Fi              Mike Relon Makiling
# 318               Comedy, Drama, Romance                     Robby Grewal
# 348                          Documentary                        Yue Jiang
# ...                                  ...                              ...
# 2792                              Comedy             Mohammad Hadi Karimi
# 2926                         Documentary               Joseph C. Stillman
# 3004                    Horror, Thriller                Brandon E. Brooks
# 3009                         Documentary  Reuben Atlas, Samuel D. Pollard
# 3154                                 NaN                   Jin-young Park
#
#       ...                                             Poster IMDB Rating  \
# 90    ...  https://m.media-amazon.com/images/M/MV5BMTc5OT...         5.9
# 95    ...  https://m.media-amazon.com/images/M/MV5BMjM3Mz...         6.3
# 138   ...  https://m.media-amazon.com/images/M/MV5BMmVhYj...         5.6
# 318   ...  https://m.media-amazon.com/images/M/MV5BNDhiOW...         5.9
# 348   ...                                                NaN         NaN
# ...   ...                                                ...         ...
# 2792  ...  https://m.media-amazon.com/images/M/MV5BMTZhZD...         4.0
# 2926  ...                                                NaN         NaN
# 3004  ...                                                NaN         4.3
# 3009  ...                                                NaN         NaN
# 3154  ...                                                NaN         NaN
#
#      IMDB Votes DVD Release Date                Production Day of Release  \
# 90           31              NaN                       NaN         Friday
# 95           57              NaN                       NaN         Friday
# 138          16              NaN                       NaN         Friday
# 318         809      09 Jun 2009       Mavrick Productions         Friday
# 348         NaN              NaN                       NaN         Friday
# ...         ...              ...                       ...            ...
# 2792          5              NaN                       NaN         Friday
# 2926        NaN              NaN              Indie Rights      Wednesday
# 3004          7              NaN                       NaN         Friday
# 3009        NaN              NaN                       NaN         Friday
# 3154        NaN              NaN  CJ Entertainment America         Friday
#
#      Month of Release  Year of Release Revenue (Millions) Runtime (Min)
# 90               June             2008           1.200000          None
# 95               June             2008           0.000250          None
# 138            August             2008          41.412264          None
# 318             March             2009           1.550000          None
# 348               May             2009           0.750000          None
# ...               ...              ...                ...           ...
# 2792             June             2017           0.010000          None
# 2926         December             2017           0.400000          None
# 3004            March             2018          34.764055          None
# 3009            April             2018           0.002621          None
# 3154         December             2018           0.186078          None
#
# [63 rows x 26 columns]

# %%
movie_df.loc[3004,"Runtime (Min)"]=85

# %%
movie_df=movie_df[(movie_df.Rating !="12") & (movie_df.Rating !="Approved") & (movie_df.Rating !="NOT RATED") & (movie_df.Rating !="Not Rated") & (movie_df.Rating !="TV-13") & (movie_df.Rating !="TV-14") & (movie_df.Rating !="TV-G") & (movie_df.Rating !="TV-MA") & (movie_df.Rating !="TV-PG") & (movie_df.Rating !="TV-Y") & (movie_df.Rating !="TV-Y") & (movie_df.Rating !="TV-Y7") & (movie_df.Rating !="UNRATED") & (movie_df.Rating !="Unrated")]
# print(movie_df.loc[movie_df["Rating"]=="GP"])
movie_df.loc[1658,"Rating"]="PG"
grouped_movie_rating=movie_df.groupby(["Rating"]).count()
grouped_movie_rating
# Out:
#         TMDB ID  Title  Release Date  Budget  Revenue  IMDB ID  Runtime  \
# Rating
# G            41     41            41      41       41       41       41
# NC-17         3      3             3       3        3        3        3
# PG          340    340           340     340      340      340      340
# PG-13       909    909           909     909      909      909      909
# R          1267   1267          1267    1267     1267     1267     1266
#
#         Genre  Director  Writer  ...  Poster  IMDB Rating  IMDB Votes  \
# Rating                           ...
# G          41        41      39  ...      41           41          41
# NC-17       3         3       3  ...       3            3           3
# PG        340       340     329  ...     339          340         340
# PG-13     909       909     902  ...     909          909         909
# R        1267      1267    1257  ...    1267         1267        1267
#
#         DVD Release Date  Production  Day of Release  Month of Release  \
# Rating
# G                     37          39              41                41
# NC-17                  3           3               3                 3
# PG                   323         333             340               340
# PG-13                875         884             909               909
# R                   1195        1224            1267              1267
#
#         Year of Release  Revenue (Millions)  Runtime (Min)
# Rating
# G                    41                  41             41
# NC-17                 3                   3              3
# PG                  340                 340            340
# PG-13               909                 909            909
# R                  1267                1267           1266
#
# [5 rows x 25 columns]

# %%
q75,q25=np.percentile(movie_df["Revenue"],[75,25])
inf_iqr=q75-q25
upperbound=q75+(1.5*inf_iqr)
lowerbound=q25-(1.5*inf_iqr)
q25
movie_df=movie_df.loc[movie_df["Revenue"]>q25]
# Out:
# 1777016.0

# %%
movie_df=movie_df.copy()
movie_df["Primary Genre"]=None
for index, row in movie_df.iterrows():
    movie_df.loc[index,"Primary Genre"]=str(row["Genre"]).split(",")[0]
movie_df.loc[294,"Primary Genre"]="Drama"
movie_df.loc[2358,"Primary Genre"]="Action"

# %%
movie_df
# Out:
#       TMDB ID            Title Release Date       Budget       Revenue  \
# 2       13971       Wild Child   2008-01-01   20000000.0  2.197234e+07
# 4       14423     First Sunday   2008-01-11          0.0  3.880462e+07
# 5        7191      Cloverfield   2008-01-15   25000000.0  1.707640e+08
# 7       13121            Teeth   2008-01-18    2000000.0  2.340110e+06
# 9        6687    Transsiberian   2008-01-18   15000000.0  5.926410e+06
# ...       ...              ...          ...          ...           ...
# 3166   297802          Aquaman   2018-12-21  160000000.0  1.143689e+09
# 3167   503616       Second Act   2018-12-21   16000000.0  7.228223e+07
# 3168   424783        Bumblebee   2018-12-21  135000000.0  4.658950e+08
# 3169   426563  Holmes & Watson   2018-12-25   42000000.0  4.046279e+07
# 3170   429197             Vice   2018-12-25   60000000.0  6.626640e+07
#
#         IMDB ID Rating  Runtime                               Genre  \
# 2     tt1024255  PG-13  124 min              Comedy, Drama, Romance
# 4     tt0486578  PG-13   96 min                Comedy, Crime, Drama
# 5     tt1060277  PG-13   85 min            Horror, Sci-Fi, Thriller
# 7     tt0780622      R   94 min   Comedy, Fantasy, Horror, Thriller
# 9     tt0800241      R  111 min     Crime, Drama, Mystery, Thriller
# ...         ...    ...      ...                                 ...
# 3166  tt1477834  PG-13  143 min  Action, Adventure, Fantasy, Sci-Fi
# 3167  tt2126357  PG-13  103 min              Comedy, Drama, Romance
# 3168  tt4701182  PG-13  114 min           Action, Adventure, Sci-Fi
# 3169  tt1255919  PG-13   90 min              Comedy, Crime, Mystery
# 3170  tt6266538      R  132 min            Biography, Comedy, Drama
#
#                    Director  ... IMDB Rating IMDB Votes DVD Release Date  \
# 2                Nick Moore  ...         6.1     46,716      17 Nov 2009
# 4          David E. Talbert  ...         4.5      9,203      13 May 2008
# 5               Matt Reeves  ...         7.0    358,331      22 Apr 2008
# 7     Mitchell Lichtenstein  ...         5.4     39,939      06 May 2008
# 9             Brad Anderson  ...         6.7     48,581      04 Nov 2008
# ...                     ...  ...         ...        ...              ...
# 3166              James Wan  ...         7.0    319,236              NaN
# 3167            Peter Segal  ...         5.8     18,337      12 Mar 2019
# 3168          Travis Knight  ...         6.8    115,881      02 Apr 2019
# 3169             Etan Cohen  ...         3.8     24,394      09 Apr 2019
# 3170             Adam McKay  ...         7.2     97,207      02 Apr 2019
#
#                  Production Day of Release Month of Release Year of Release  \
# 2        Universal Pictures        Tuesday          January            2008
# 4                       NaN         Friday          January            2008
# 5                 Paramount        Tuesday          January            2008
# 7      Roadside Attractions         Friday          January            2008
# 9                First Look         Friday          January            2008
# ...                     ...            ...              ...             ...
# 3166  Warner Bros. Pictures         Friday         December            2018
# 3167               STXfilms         Friday         December            2018
# 3168     Paramount Pictures         Friday         December            2018
# 3169      Columbia Pictures        Tuesday         December            2018
# 3170     Annapurna Pictures        Tuesday         December            2018
#
#       Revenue (Millions) Runtime (Min) Primary Genre
# 2              21.972336           124        Comedy
# 4              38.804615            96        Comedy
# 5             170.764026            85        Horror
# 7               2.340110            94        Comedy
# 9               5.926410           111         Crime
# ...                  ...           ...           ...
# 3166         1143.689193           143        Action
# 3167           72.282227           103        Comedy
# 3168          465.895025           114        Action
# 3169           40.462793            90        Comedy
# 3170           66.266401           132     Biography
#
# [2058 rows x 27 columns]

# %%
movie_df.to_csv(os.path.join("Resources","MovieData_Clean.csv"),index=False)
