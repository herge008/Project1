# %%
import os
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import time

# %%
csvpath=os.path.join("..","Resources","MovieData_Clean.csv")
movie_df=pd.read_csv(csvpath)

# %%
movie_df
# Out:
#       TMDB ID            Title Release Date       Budget       Revenue  \
# 0       13971       Wild Child   2008-01-01   20000000.0  2.197234e+07
# 1       14423     First Sunday   2008-01-11          0.0  3.880462e+07
# 2        7191      Cloverfield   2008-01-15   25000000.0  1.707640e+08
# 3       13121            Teeth   2008-01-18    2000000.0  2.340110e+06
# 4        6687    Transsiberian   2008-01-18   15000000.0  5.926410e+06
# ...       ...              ...          ...          ...           ...
# 2053   297802          Aquaman   2018-12-21  160000000.0  1.143689e+09
# 2054   503616       Second Act   2018-12-21   16000000.0  7.228223e+07
# 2055   424783        Bumblebee   2018-12-21  135000000.0  4.658950e+08
# 2056   426563  Holmes & Watson   2018-12-25   42000000.0  4.046279e+07
# 2057   429197             Vice   2018-12-25   60000000.0  6.626640e+07
#
#         IMDB ID Rating  Runtime                               Genre  \
# 0     tt1024255  PG-13  124 min              Comedy, Drama, Romance
# 1     tt0486578  PG-13   96 min                Comedy, Crime, Drama
# 2     tt1060277  PG-13   85 min            Horror, Sci-Fi, Thriller
# 3     tt0780622      R   94 min   Comedy, Fantasy, Horror, Thriller
# 4     tt0800241      R  111 min     Crime, Drama, Mystery, Thriller
# ...         ...    ...      ...                                 ...
# 2053  tt1477834  PG-13  143 min  Action, Adventure, Fantasy, Sci-Fi
# 2054  tt2126357  PG-13  103 min              Comedy, Drama, Romance
# 2055  tt4701182  PG-13  114 min           Action, Adventure, Sci-Fi
# 2056  tt1255919  PG-13   90 min              Comedy, Crime, Mystery
# 2057  tt6266538      R  132 min            Biography, Comedy, Drama
#
#                    Director  ... IMDB Rating IMDB Votes DVD Release Date  \
# 0                Nick Moore  ...         6.1     46,716      17 Nov 2009
# 1          David E. Talbert  ...         4.5      9,203      13 May 2008
# 2               Matt Reeves  ...         7.0    358,331      22 Apr 2008
# 3     Mitchell Lichtenstein  ...         5.4     39,939      06 May 2008
# 4             Brad Anderson  ...         6.7     48,581      04 Nov 2008
# ...                     ...  ...         ...        ...              ...
# 2053              James Wan  ...         7.0    319,236              NaN
# 2054            Peter Segal  ...         5.8     18,337      12 Mar 2019
# 2055          Travis Knight  ...         6.8    115,881      02 Apr 2019
# 2056             Etan Cohen  ...         3.8     24,394      09 Apr 2019
# 2057             Adam McKay  ...         7.2     97,207      02 Apr 2019
#
#                  Production Day of Release Month of Release Year of Release  \
# 0        Universal Pictures        Tuesday          January            2008
# 1                       NaN         Friday          January            2008
# 2                 Paramount        Tuesday          January            2008
# 3      Roadside Attractions         Friday          January            2008
# 4                First Look         Friday          January            2008
# ...                     ...            ...              ...             ...
# 2053  Warner Bros. Pictures         Friday         December            2018
# 2054               STXfilms         Friday         December            2018
# 2055     Paramount Pictures         Friday         December            2018
# 2056      Columbia Pictures        Tuesday         December            2018
# 2057     Annapurna Pictures        Tuesday         December            2018
#
#       Revenue (Millions) Runtime (Min) Primary Genre
# 0              21.972336         124.0        Comedy
# 1              38.804615          96.0        Comedy
# 2             170.764026          85.0        Horror
# 3               2.340110          94.0        Comedy
# 4               5.926410         111.0         Crime
# ...                  ...           ...           ...
# 2053         1143.689193         143.0        Action
# 2054           72.282227         103.0        Comedy
# 2055          465.895025         114.0        Action
# 2056           40.462793          90.0        Comedy
# 2057           66.266401         132.0     Biography
#
# [2058 rows x 27 columns]

# %%
grouped_movie_rating=movie_df.groupby(["Rating"]).min()
grouped_movie_rating
# Out:
#         TMDB ID                      Title Release Date     Budget  \
# Rating
# G         10193         A Beautiful Planet   2008-03-03        0.0
# NC-17     76025  Blue Is the Warmest Color   2011-12-02  4300000.0
# PG          767      2016: Obama's America   2008-02-14        0.0
# PG-13       155        10 Cloverfield Lane   2008-01-01        0.0
# R           189                        '71   2008-01-18        0.0
#
#            Revenue    IMDB ID  Runtime                             Genre  \
# Rating
# G        2892597.0  tt0052618  101 min  Adventure, Comedy, Drama, Family
# NC-17   10165694.0  tt1723811  101 min                             Drama
# PG       1829917.0  tt0063415  100 min         Action, Adventure, Comedy
# PG-13    1784763.0  tt0068161  100 min                 Action, Adventure
# R        1777043.0  tt0064118  100 min                            Action
#
#                                  Director  \
# Rating
# G                          Andrew Stanton
# NC-17                 Abdellatif Kechiche
# PG      Aaron Horvath, Peter Rida Michail
# PG-13         Abby Kohn, Marc Silverstein
# R                            Aaron Sorkin
#
#                                                      Plot  ...  \
# Rating                                                     ...
# G       A college professor bonds with an abandoned do...  ...
# NC-17   A sex addict's carefully cultivated private li...  ...
# PG      78-year-old Carl Fredricksen travels to Paradi...  ...
# PG-13   "21" is the fact-based story about six MIT stu...  ...
# R       10 years after a global economic collapse, a h...  ...
#
#                                  Country  \
# Rating
# G       Canada, USA, France, Germany, UK
# NC-17    France, Tunisia, Belgium, Spain
# PG                      Argentina, Spain
# PG-13                          Australia
# R                       Argentina, Spain
#
#                                                    Poster IMDB Rating  \
# Rating
# G       https://m.media-amazon.com/images/M/MV5BMTM2NT...         1.6
# NC-17   https://m.media-amazon.com/images/M/MV5BMTQ3Mz...         7.2
# PG      https://m.media-amazon.com/images/M/MV5BM2ZkMG...         1.4
# PG-13   https://m.media-amazon.com/images/M/MV5BMDA0MD...         1.9
# R       https://m.media-amazon.com/images/M/MV5BM2E4Nj...         3.0
#
#         IMDB Votes Day of Release Month of Release Year of Release  \
# Rating
# G            1,000         Friday            April            2008
# NC-17      128,462         Friday         December            2011
# PG           1,547         Friday            April            2008
# PG-13    1,073,469         Friday            April            2008
# R        1,045,727         Friday            April            2008
#
#         Revenue (Millions)  Runtime (Min)  Primary Genre
# Rating
# G                 2.892597           39.0      Adventure
# NC-17            10.165694          101.0          Drama
# PG                1.829917           78.0         Action
# PG-13             1.784763           75.0         Action
# R                 1.777043           75.0         Action
#
# [5 rows x 21 columns]

# %% [markdown]
# # Determine the Highest Earning Genres NOT taking subgenres into account

# %%
movie_df=movie_df[movie_df["Primary Genre"]!="Short"]
movie_df=movie_df.copy()
grouped_movie_df=movie_df.groupby(["Primary Genre"])
average_df=grouped_movie_df.mean().sort_values("Revenue (Millions)")
average_df
# Out:
#                      TMDB ID        Budget       Revenue  IMDB Rating  \
# Primary Genre
# Documentary    213618.180000  3.209186e+06  1.463406e+07     7.052083
# Family          49852.000000  9.000000e+07  1.617896e+07     5.800000
# Romance         97876.333333  1.730000e+07  4.505895e+07     6.966667
# Crime          193823.578947  2.146719e+07  4.733260e+07     6.593684
# Fantasy         72595.600000  1.940000e+07  5.217272e+07     5.940000
# Music          242291.500000  9.000000e+06  5.348648e+07     8.100000
# Drama          171977.448795  1.919927e+07  6.119797e+07     6.729607
# Biography      233364.291429  2.028395e+07  6.386568e+07     7.022286
# Comedy         151929.598712  2.249408e+07  6.676155e+07     6.193118
# Mystery         61270.000000  2.160000e+07  7.201738e+07     6.160000
# Horror         177493.173077  1.250654e+07  8.439949e+07     5.832039
# Sci-Fi          92317.500000  1.490000e+07  8.753422e+07     7.400000
# Thriller       132363.000000  2.500000e+07  1.159222e+08     7.600000
# Adventure      157994.333333  6.438206e+07  2.058607e+08     6.522857
# Action         156152.815217  7.531177e+07  2.293447e+08     6.345290
# Animation      164459.051282  7.874741e+07  3.033410e+08     6.706410
#
#                Year of Release  Revenue (Millions)  Runtime (Min)
# Primary Genre
# Documentary        2013.200000           14.634055      87.200000
# Family             2010.000000           16.178959      92.000000
# Romance            2011.666667           45.058947     119.000000
# Crime              2013.378947           47.332605     114.494737
# Fantasy            2011.600000           52.172719      96.200000
# Music              2013.500000           53.486483     106.500000
# Drama              2012.921687           61.197968     112.885542
# Biography          2014.080000           63.865684     117.765714
# Comedy             2012.399142           66.761546     104.012876
# Mystery            2011.400000           72.017381     107.600000
# Horror             2013.038462           84.399494      94.766990
# Sci-Fi             2011.500000           87.534217     127.500000
# Thriller           2013.000000          115.922175      70.000000
# Adventure          2012.752381          205.860718     114.115385
# Action             2013.148551          229.344685     113.431942
# Animation          2013.314103          303.340974      94.166667

# %%
# Plot the average revenue in millions for each primary genre
plt.bar(average_df.index.values,average_df["Revenue (Millions)"])
plt.title("Total Primary Genre Earnings")
plt.xticks(rotation=90)
plt.ylabel("Revenue (Millions $)")
imagepath=os.path.join("..","Images",f"BarPlot_TotalGenre_Revenue.png")
plt.savefig(imagepath)
plt.show()

# %%
# movie_df=movie_df.sort_values("Year of Release")
# movie_df
# grouped_movie_df=movie_df.groupby(["Primary Genre","Year of Release"])
# grouped_movie_df.count()

# %% [markdown]
# # Determine the Highest earning Genres taking subgenres into account

# %%
# Create a dataframe that accounts for each genre a movie holds
temp_df=pd.DataFrame()
index_counter=movie_df.index.max()+1
for index,row in movie_df.iterrows():
    
    for genre in row["Genre"].split(", "):
        if row["Primary Genre"]!= genre:
            new_row=row
            new_row["Primary Genre"]=genre
            new_row=new_row.to_frame().T
            new_row.reset_index(drop=True,inplace=True)
            new_row["new index"]=index_counter
            temp_df=temp_df.append(new_row)
            index_counter+=1

# %%
temp_df.set_index('new index',drop=True,inplace=True)

# %%
movie_df["new index"]=movie_df.index.values
movie_df.set_index("new index", inplace=True,drop=True)

# %%
#Combine the 2 dataframes
split_genre_df=movie_df.append(temp_df,sort=True)
split_genre_df=split_genre_df.loc[(split_genre_df["Primary Genre"]!="News")]
split_genre_df=split_genre_df.loc[(split_genre_df["Primary Genre"]!="Adult")]
split_genre_df=split_genre_df.loc[(split_genre_df["Primary Genre"]!="Short")]
split_genre_df.loc[split_genre_df["Primary Genre"]=="Music"]
split_genre_df
# Out:
#                                                       Actors  \
# new index
# 0          Emma Roberts, Lexi Ainsworth, Shelby Young, Jo...
# 1          Ice Cube, Katt Williams, Tracy Morgan, Loretta...
# 2          Lizzy Caplan, Jessica Lucas, T.J. Miller, Mich...
# 3          Jess Weixler, John Hensley, Josh Pais, Hale Ap...
# 4          Woody Harrelson, Emily Mortimer, Ben Kingsley,...
# ...                                                      ...
# 6462       Hailee Steinfeld, Jorge Lendeborg Jr., John Ce...
# 6463       Will Ferrell, John C. Reilly, Rebecca Hall, Ro...
# 6464       Will Ferrell, John C. Reilly, Rebecca Hall, Ro...
# 6465       Christian Bale, Amy Adams, Steve Carell, Sam R...
# 6466       Christian Bale, Amy Adams, Steve Carell, Sam R...
#
#                                                     Awards    Budget  \
# new index
# 0                                                      NaN     2e+07
# 1                                                      NaN         0
# 2                                 5 wins & 30 nominations.   2.5e+07
# 3                                 2 wins & 10 nominations.     2e+06
# 4                                 2 wins & 11 nominations.   1.5e+07
# ...                                                    ...       ...
# 6462                               1 win & 11 nominations.  1.35e+08
# 6463                               4 wins & 4 nominations.   4.2e+07
# 6464                               4 wins & 4 nominations.   4.2e+07
# 6465       Won 1 Oscar. Another 32 wins & 129 nominations.     6e+07
# 6466       Won 1 Oscar. Another 32 wins & 129 nominations.     6e+07
#
#                                  Country DVD Release Date Day of Release  \
# new index
# 0                        USA, UK, France      17 Nov 2009        Tuesday
# 1                                    USA      13 May 2008         Friday
# 2                                    USA      22 Apr 2008        Tuesday
# 3                                    USA      06 May 2008         Friday
# 4          UK, Germany, Spain, Lithuania      04 Nov 2008         Friday
# ...                                  ...              ...            ...
# 6462                          China, USA      02 Apr 2019         Friday
# 6463                         USA, Canada      09 Apr 2019        Tuesday
# 6464                         USA, Canada      09 Apr 2019        Tuesday
# 6465                                 USA      02 Apr 2019        Tuesday
# 6466                                 USA      02 Apr 2019        Tuesday
#
#                         Director                              Genre  \
# new index
# 0                     Nick Moore             Comedy, Drama, Romance
# 1               David E. Talbert               Comedy, Crime, Drama
# 2                    Matt Reeves           Horror, Sci-Fi, Thriller
# 3          Mitchell Lichtenstein  Comedy, Fantasy, Horror, Thriller
# 4                  Brad Anderson    Crime, Drama, Mystery, Thriller
# ...                          ...                                ...
# 6462               Travis Knight          Action, Adventure, Sci-Fi
# 6463                  Etan Cohen             Comedy, Crime, Mystery
# 6464                  Etan Cohen             Comedy, Crime, Mystery
# 6465                  Adam McKay           Biography, Comedy, Drama
# 6466                  Adam McKay           Biography, Comedy, Drama
#
#              IMDB ID IMDB Rating  ... Rating Release Date      Revenue  \
# new index                         ...
# 0          tt1024255         6.1  ...  PG-13   2008-01-01  2.19723e+07
# 1          tt0486578         4.5  ...  PG-13   2008-01-11  3.88046e+07
# 2          tt1060277           7  ...  PG-13   2008-01-15  1.70764e+08
# 3          tt0780622         5.4  ...      R   2008-01-18  2.34011e+06
# 4          tt0800241         6.7  ...      R   2008-01-18  5.92641e+06
# ...              ...         ...  ...    ...          ...          ...
# 6462       tt4701182         6.8  ...  PG-13   2018-12-21  4.65895e+08
# 6463       tt1255919         3.8  ...  PG-13   2018-12-25  4.04628e+07
# 6464       tt1255919         3.8  ...  PG-13   2018-12-25  4.04628e+07
# 6465       tt6266538         7.2  ...      R   2018-12-25  6.62664e+07
# 6466       tt6266538         7.2  ...      R   2018-12-25  6.62664e+07
#
#           Revenue (Millions)  Runtime Runtime (Min) TMDB ID            Title  \
# new index
# 0                    21.9723  124 min           124   13971       Wild Child
# 1                    38.8046   96 min            96   14423     First Sunday
# 2                    170.764   85 min            85    7191      Cloverfield
# 3                    2.34011   94 min            94   13121            Teeth
# 4                    5.92641  111 min           111    6687    Transsiberian
# ...                      ...      ...           ...     ...              ...
# 6462                 465.895  114 min           114  424783        Bumblebee
# 6463                 40.4628   90 min            90  426563  Holmes & Watson
# 6464                 40.4628   90 min            90  426563  Holmes & Watson
# 6465                 66.2664  132 min           132  429197             Vice
# 6466                 66.2664  132 min           132  429197             Vice
#
#                                                       Writer Year of Release
# new index
# 0                                                  Lucy Dahl            2008
# 1                                           David E. Talbert            2008
# 2                                               Drew Goddard            2008
# 3                                      Mitchell Lichtenstein            2008
# 4                                 Brad Anderson, Will Conroy            2008
# ...                                                      ...             ...
# 6462                                        Christina Hodson            2018
# 6463       Etan Cohen, Arthur Conan Doyle (Sherlock Holme...            2018
# 6464       Etan Cohen, Arthur Conan Doyle (Sherlock Holme...            2018
# 6465                                              Adam McKay            2018
# 6466                                              Adam McKay            2018
#
# [6453 rows x 27 columns]

# %%
split_genre_df["Revenue (Millions)"]=split_genre_df["Revenue (Millions)"].astype(float)
split_genre_df["Year of Release"]=split_genre_df["Year of Release"].astype(int)
grouped_frame=split_genre_df.groupby(["Primary Genre"]).mean().sort_values("Revenue (Millions)")
# grouped_frame=grouped_frame.drop(index=["News","Adult","Short"])
grouped_frame
# Out:
#                Revenue (Millions)  Year of Release
# Primary Genre
# Documentary             14.634055      2013.200000
# Biography               64.342938      2014.099526
# Crime                   66.674681      2013.209913
# History                 72.130031      2013.554622
# Sport                   72.362230      2012.830769
# Drama                   74.263065      2013.155678
# Horror                  82.632321      2013.397196
# Romance                 84.704597      2012.257336
# War                     97.175799      2013.236842
# Mystery                 98.310088      2013.196154
# Music                   98.803328      2013.367089
# Western                109.667701      2013.130435
# Thriller               113.129512      2013.164537
# Comedy                 122.888796      2012.751309
# Action                 231.073783      2013.124361
# Fantasy                257.972543      2012.960912
# Family                 266.305817      2012.726190
# Musical                284.754770      2013.555556
# Sci-Fi                 290.758060      2013.287671
# Animation              301.479731      2013.280255
# Adventure              331.415483      2013.207877

# %%
plt.bar(grouped_frame.index.values,grouped_frame["Revenue (Millions)"])
plt.title("Total Genre/Subgenre Earnings")
plt.xticks(rotation=90)
plt.ylabel("Revenue (Millions $)")
imagepath=os.path.join("..","Images",f"BarPlot_TotalGenreandSubs_Revenue.png")
plt.savefig(imagepath)
plt.show()

# %% [markdown]
# # See if the season affects the Genre earnings

# %%
# Insert a season for each row in original data frame and split genre dataframe
spring=["March","April","May"]
summer=["June","July","August"]
fall=["September","October","November"]
winter=["December","January","February"]
split_genre_df["Season"]=None
movie_df["Season"]=None
for index,row in split_genre_df.iterrows():
    if(row["Month of Release"] in summer):
        split_genre_df.loc[index,"Season"]="Summer"
    elif(row["Month of Release"] in spring):
        split_genre_df.loc[index,"Season"]="Spring"
    elif(row["Month of Release"] in winter):
        split_genre_df.loc[index,"Season"]="Winter"
    elif(row["Month of Release"] in fall):
        split_genre_df.loc[index,"Season"]="Fall"
        
for index,row in movie_df.iterrows():
    if(row["Month of Release"] in summer):
        movie_df.loc[index,"Season"]="Summer"
    elif(row["Month of Release"] in spring):
        movie_df.loc[index,"Season"]="Spring"
    elif(row["Month of Release"] in winter):
        movie_df.loc[index,"Season"]="Winter"
    elif(row["Month of Release"] in fall):
        movie_df.loc[index,"Season"]="Fall"

# %%
# Function to plot the seasonal genre earnings. Takes the season and the dataframe you are working with.
def seasonalPlot(season,split=False):
    subtitle=""
    if split:
        subtitle='andSub'
        var_df=split_genre_df
    else:
        var_df=movie_df
    df=var_df[var_df["Season"]==season]
    df=df.sort_values("Revenue (Millions)")
    df=df.groupby(["Primary Genre"])["Revenue (Millions)"].median().sort_values()
#     df.drop("Year of Release",axis=1,inplace=True)
    bar=df.plot.bar()
    plt.title(f"Genre vs. Median Revenue in the {season}")
    plt.ylabel("Revenue (Millions)")
    plt.xlabel("Genre")
    plt.ylim(0,500)
    plt.show()
    
    
    imagepath=os.path.join("..","Images",f"BarPlot_{season}_Genre{subtitle}_Revenue.png")
    fig = bar.get_figure()
    fig.savefig(imagepath)

# %%
seasonalPlot("Fall")
seasonalPlot("Summer")
seasonalPlot("Spring")
seasonalPlot("Winter")
print("All genres included Below")
seasonalPlot("Fall",True)
seasonalPlot("Summer",True)
seasonalPlot("Spring",True)
seasonalPlot("Winter",True)
# Out:
# All genres included Below
